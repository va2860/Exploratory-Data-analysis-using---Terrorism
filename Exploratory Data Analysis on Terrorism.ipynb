# %% [markdown]
# # Made By Vedansh Rai

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv(r'C:/Users/anike/Downloads/Global Terrorism - START data/globalterrorismdb_0718dist.csv', encoding='latin-1', low_memory=False)

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
No_of_cols=df.columns.nunique()
print("There are total %d columns in the data"%No_of_cols)
# Out:
# There are total 135 columns in the data

# %%
df=df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','region_txt':'Region',
                             'provstate':'State','city':'City','attacktype1_txt':'Attack_type','targtype1_txt':'Target_type',
                             'targsubtype1_txt':'Target_subtype','gname':'Gang_name','weaptype1_txt':'Weapon_type'})

# %%
df
# Out:
#              eventid  Year  Month  Day approxdate  extended resolution  \
# 0       197000000001  1970      7    2        NaN         0        NaN
# 1       197000000002  1970      0    0        NaN         0        NaN
# 2       197001000001  1970      1    0        NaN         0        NaN
# 3       197001000002  1970      1    0        NaN         0        NaN
# 4       197001000003  1970      1    0        NaN         0        NaN
# ...              ...   ...    ...  ...        ...       ...        ...
# 181686  201712310022  2017     12   31        NaN         0        NaN
# 181687  201712310029  2017     12   31        NaN         0        NaN
# 181688  201712310030  2017     12   31        NaN         0        NaN
# 181689  201712310031  2017     12   31        NaN         0        NaN
# 181690  201712310032  2017     12   31        NaN         0        NaN
#
#         country             Country  region  ... addnotes  \
# 0            58  Dominican Republic       2  ...      NaN
# 1           130              Mexico       1  ...      NaN
# 2           160         Philippines       5  ...      NaN
# 3            78              Greece       8  ...      NaN
# 4           101               Japan       4  ...      NaN
# ...         ...                 ...     ...  ...      ...
# 181686      182             Somalia      11  ...      NaN
# 181687      200               Syria      10  ...      NaN
# 181688      160         Philippines       5  ...      NaN
# 181689       92               India       6  ...      NaN
# 181690      160         Philippines       5  ...      NaN
#
#                                                    scite1  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0                           PGIS        0         0        0       0      NaN
# 1                           PGIS        0         1        1       1      NaN
# 2                           PGIS       -9        -9        1       1      NaN
# 3                           PGIS       -9        -9        1       1      NaN
# 4                           PGIS       -9        -9        1       1      NaN
# ...                          ...      ...       ...      ...     ...      ...
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [181691 rows x 135 columns]

# %%
terrorism_df=df[['Year','Month','Day','Country','Region','State','City','Attack_type','Target_type','Target_subtype','Gang_name','Weapon_type']]

# %%
terrorism_df
# Out:
#         Year  Month  Day             Country                       Region  \
# 0       1970      7    2  Dominican Republic  Central America & Caribbean
# 1       1970      0    0              Mexico                North America
# 2       1970      1    0         Philippines               Southeast Asia
# 3       1970      1    0              Greece               Western Europe
# 4       1970      1    0               Japan                    East Asia
# ...      ...    ...  ...                 ...                          ...
# 181686  2017     12   31             Somalia           Sub-Saharan Africa
# 181687  2017     12   31               Syria   Middle East & North Africa
# 181688  2017     12   31         Philippines               Southeast Asia
# 181689  2017     12   31               India                   South Asia
# 181690  2017     12   31         Philippines               Southeast Asia
#
#                   State           City                     Attack_type  \
# 0                   NaN  Santo Domingo                   Assassination
# 1               Federal    Mexico city     Hostage Taking (Kidnapping)
# 2                Tarlac        Unknown                   Assassination
# 3                Attica         Athens               Bombing/Explosion
# 4               Fukouka        Fukouka  Facility/Infrastructure Attack
# ...                 ...            ...                             ...
# 181686  Middle Shebelle  Ceelka Geelow                   Armed Assault
# 181687         Lattakia         Jableh               Bombing/Explosion
# 181688      Maguindanao       Kubentog  Facility/Infrastructure Attack
# 181689          Manipur         Imphal               Bombing/Explosion
# 181690      Maguindanao  Cotabato City               Bombing/Explosion
#
#                         Target_type  \
# 0       Private Citizens & Property
# 1           Government (Diplomatic)
# 2               Journalists & Media
# 3           Government (Diplomatic)
# 4           Government (Diplomatic)
# ...                             ...
# 181686                     Military
# 181687                     Military
# 181688  Private Citizens & Property
# 181689         Government (General)
# 181690                      Unknown
#
#                                            Target_subtype  \
# 0                                          Named Civilian
# 1       Diplomatic Personnel (outside of embassy, cons...
# 2                         Radio Journalist/Staff/Facility
# 3                                       Embassy/Consulate
# 4                                       Embassy/Consulate
# ...                                                   ...
# 181686                                Military Checkpoint
# 181687      Military Barracks/Base/Headquarters/Checkpost
# 181688                          House/Apartment/Residence
# 181689                Government Building/Facility/Office
# 181690                                                NaN
#
#                                          Gang_name Weapon_type
# 0                                           MANO-D     Unknown
# 1               23rd of September Communist League     Unknown
# 2                                          Unknown     Unknown
# 3                                          Unknown  Explosives
# 4                                          Unknown  Incendiary
# ...                                            ...         ...
# 181686                                  Al-Shabaab    Firearms
# 181687                           Muslim extremists  Explosives
# 181688  Bangsamoro Islamic Freedom Movement (BIFM)  Incendiary
# 181689                                     Unknown  Explosives
# 181690                                     Unknown  Explosives
#
# [181691 rows x 12 columns]

# %%
terrorism_df.loc['Target_subtype'] = terrorism_df['Target_subtype'].fillna('others')

# %%
terrorism_df['State']=terrorism_df['State'].fillna('Unknown')

# %%
terrorism_df['City']=terrorism_df['City'].fillna('Unknown')

# %%
terrorism_df.replace( {"Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)": "Vehicle"},inplace = True)

# %%
terrorism_df
# Out:
#                   Year  Month   Day             Country  \
# 0               1970.0    7.0   2.0  Dominican Republic
# 1               1970.0    0.0   0.0              Mexico
# 2               1970.0    1.0   0.0         Philippines
# 3               1970.0    1.0   0.0              Greece
# 4               1970.0    1.0   0.0               Japan
# ...                ...    ...   ...                 ...
# 181687          2017.0   12.0  31.0               Syria
# 181688          2017.0   12.0  31.0         Philippines
# 181689          2017.0   12.0  31.0               India
# 181690          2017.0   12.0  31.0         Philippines
# Target_subtype     NaN    NaN   NaN                 NaN
#
#                                      Region        State           City  \
# 0               Central America & Caribbean      Unknown  Santo Domingo
# 1                             North America      Federal    Mexico city
# 2                            Southeast Asia       Tarlac        Unknown
# 3                            Western Europe       Attica         Athens
# 4                                 East Asia      Fukouka        Fukouka
# ...                                     ...          ...            ...
# 181687           Middle East & North Africa     Lattakia         Jableh
# 181688                       Southeast Asia  Maguindanao       Kubentog
# 181689                           South Asia      Manipur         Imphal
# 181690                       Southeast Asia  Maguindanao  Cotabato City
# Target_subtype                          NaN      Unknown        Unknown
#
#                                    Attack_type                  Target_type  \
# 0                                Assassination  Private Citizens & Property
# 1                  Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                                Assassination          Journalists & Media
# 3                            Bombing/Explosion      Government (Diplomatic)
# 4               Facility/Infrastructure Attack      Government (Diplomatic)
# ...                                        ...                          ...
# 181687                       Bombing/Explosion                     Military
# 181688          Facility/Infrastructure Attack  Private Citizens & Property
# 181689                       Bombing/Explosion         Government (General)
# 181690                       Bombing/Explosion                      Unknown
# Target_subtype                             NaN                          NaN
#
#                                                    Target_subtype  \
# 0                                                  Named Civilian
# 1               Diplomatic Personnel (outside of embassy, cons...
# 2                                 Radio Journalist/Staff/Facility
# 3                                               Embassy/Consulate
# 4                                               Embassy/Consulate
# ...                                                           ...
# 181687              Military Barracks/Base/Headquarters/Checkpost
# 181688                                  House/Apartment/Residence
# 181689                        Government Building/Facility/Office
# 181690                                                        NaN
# Target_subtype                                                NaN
#
#                                                  Gang_name Weapon_type
# 0                                                   MANO-D     Unknown
# 1                       23rd of September Communist League     Unknown
# 2                                                  Unknown     Unknown
# 3                                                  Unknown  Explosives
# 4                                                  Unknown  Incendiary
# ...                                                    ...         ...
# 181687                                   Muslim extremists  Explosives
# 181688          Bangsamoro Islamic Freedom Movement (BIFM)  Incendiary
# 181689                                             Unknown  Explosives
# 181690                                             Unknown  Explosives
# Target_subtype                                         NaN         NaN
#
# [181692 rows x 12 columns]

# %%
terrorism_df.shape
# Out:
# (181692, 12)

# %%
terrorism_df.isnull().sum()
# Out:
# Year                  1
# Month                 1
# Day                   1
# Country               1
# Region                1
# State                 0
# City                  0
# Attack_type           1
# Target_type           1
# Target_subtype    10374
# Gang_name             1
# Weapon_type           1
# dtype: int64

# %%
terrorism_df.head(10)
# Out:
#      Year  Month  Day             Country                       Region  \
# 0  1970.0    7.0  2.0  Dominican Republic  Central America & Caribbean
# 1  1970.0    0.0  0.0              Mexico                North America
# 2  1970.0    1.0  0.0         Philippines               Southeast Asia
# 3  1970.0    1.0  0.0              Greece               Western Europe
# 4  1970.0    1.0  0.0               Japan                    East Asia
# 5  1970.0    1.0  1.0       United States                North America
# 6  1970.0    1.0  2.0             Uruguay                South America
# 7  1970.0    1.0  2.0       United States                North America
# 8  1970.0    1.0  2.0       United States                North America
# 9  1970.0    1.0  3.0       United States                North America
#
#         State           City                     Attack_type  \
# 0     Unknown  Santo Domingo                   Assassination
# 1     Federal    Mexico city     Hostage Taking (Kidnapping)
# 2      Tarlac        Unknown                   Assassination
# 3      Attica         Athens               Bombing/Explosion
# 4     Fukouka        Fukouka  Facility/Infrastructure Attack
# 5    Illinois          Cairo                   Armed Assault
# 6  Montevideo     Montevideo                   Assassination
# 7  California        Oakland               Bombing/Explosion
# 8   Wisconsin        Madison  Facility/Infrastructure Attack
# 9   Wisconsin        Madison  Facility/Infrastructure Attack
#
#                    Target_type  \
# 0  Private Citizens & Property
# 1      Government (Diplomatic)
# 2          Journalists & Media
# 3      Government (Diplomatic)
# 4      Government (Diplomatic)
# 5                       Police
# 6                       Police
# 7                    Utilities
# 8                     Military
# 9         Government (General)
#
#                                       Target_subtype  \
# 0                                     Named Civilian
# 1  Diplomatic Personnel (outside of embassy, cons...
# 2                    Radio Journalist/Staff/Facility
# 3                                  Embassy/Consulate
# 4                                  Embassy/Consulate
# 5    Police Building (headquarters, station, school)
# 6                    Police Security Forces/Officers
# 7                                        Electricity
# 8                Military Recruiting Station/Academy
# 9                Government Building/Facility/Office
#
#                             Gang_name Weapon_type
# 0                              MANO-D     Unknown
# 1  23rd of September Communist League     Unknown
# 2                             Unknown     Unknown
# 3                             Unknown  Explosives
# 4                             Unknown  Incendiary
# 5                  Black Nationalists    Firearms
# 6                 Tupamaros (Uruguay)    Firearms
# 7                             Unknown  Explosives
# 8                     New Year's Gang  Incendiary
# 9                     New Year's Gang  Incendiary

# %%
terrorism_df.columns.unique()
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'Region', 'State', 'City',
#        'Attack_type', 'Target_type', 'Target_subtype', 'Gang_name',
#        'Weapon_type'],
#       dtype='object')

# %%
Total_countries=terrorism_df['Country'].nunique()
print("Total %d countries were noted in the data"%Total_countries)
# Out:
# Total 205 countries were noted in the data

# %%
print(terrorism_df['Region'].unique())
# Out:
# ['Central America & Caribbean' 'North America' 'Southeast Asia'
#  'Western Europe' 'East Asia' 'South America' 'Eastern Europe'
#  'Sub-Saharan Africa' 'Middle East & North Africa' 'Australasia & Oceania'
#  'South Asia' 'Central Asia' nan]

# %%
print(terrorism_df['Attack_type'].unique())
# Out:
# ['Assassination' 'Hostage Taking (Kidnapping)' 'Bombing/Explosion'
#  'Facility/Infrastructure Attack' 'Armed Assault' 'Hijacking' 'Unknown'
#  'Unarmed Assault' 'Hostage Taking (Barricade Incident)' nan]

# %%
print(terrorism_df['Target_type'].unique())
# Out:
# ['Private Citizens & Property' 'Government (Diplomatic)'
#  'Journalists & Media' 'Police' 'Utilities' 'Military'
#  'Government (General)' 'Airports & Aircraft' 'Business'
#  'Educational Institution' 'Violent Political Party'
#  'Religious Figures/Institutions' 'Unknown' 'Transportation' 'Tourists'
#  'NGO' 'Telecommunication' 'Food or Water Supply'
#  'Terrorists/Non-State Militia' 'Other' 'Maritime' 'Abortion Related' nan]

# %%
print(terrorism_df['Target_type'].unique())
# Out:
# ['Private Citizens & Property' 'Government (Diplomatic)'
#  'Journalists & Media' 'Police' 'Utilities' 'Military'
#  'Government (General)' 'Airports & Aircraft' 'Business'
#  'Educational Institution' 'Violent Political Party'
#  'Religious Figures/Institutions' 'Unknown' 'Transportation' 'Tourists'
#  'NGO' 'Telecommunication' 'Food or Water Supply'
#  'Terrorists/Non-State Militia' 'Other' 'Maritime' 'Abortion Related' nan]

# %%
print(terrorism_df['Gang_name'].unique())
# Out:
# ['MANO-D' '23rd of September Communist League' 'Unknown' ...
#  'Minorities of Metropolitan Attacks' 'Baloch Republican Party' nan]

# %%
print(terrorism_df['Gang_name'].nunique())
# Out:
# 3537

# %%
print(terrorism_df['Weapon_type'].unique())
# Out:
# ['Unknown' 'Explosives' 'Incendiary' 'Firearms' 'Chemical' 'Melee'
#  'Sabotage Equipment' 'Vehicle' 'Fake Weapons' 'Radiological' 'Other'
#  'Biological' nan]

# %%
terrorism_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 181692 entries, 0 to Target_subtype
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Year            181691 non-null  float64
#  1   Month           181691 non-null  float64
#  2   Day             181691 non-null  float64
#  3   Country         181691 non-null  object
#  4   Region          181691 non-null  object
#  5   State           181692 non-null  object
#  6   City            181692 non-null  object
#  7   Attack_type     181691 non-null  object
#  8   Target_type     181691 non-null  object
#  9   Target_subtype  171318 non-null  object
#  10  Gang_name       181691 non-null  object
#  11  Weapon_type     181691 non-null  object
# dtypes: float64(3), object(9)
# memory usage: 18.0+ MB

# %%
terrorism_df.describe()
# Out:
#                 Year          Month            Day
# count  181691.000000  181691.000000  181691.000000
# mean     2002.638997       6.467277      15.505644
# std        13.259430       3.388303       8.814045
# min      1970.000000       0.000000       0.000000
# 25%      1991.000000       4.000000       8.000000
# 50%      2009.000000       6.000000      15.000000
# 75%      2014.000000       9.000000      23.000000
# max      2017.000000      12.000000      31.000000

# %%
terrorism_df['Country'].value_counts().head(10)
# Out:
# Country
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: count, dtype: int64

# %%
terrorism_df['Region'].value_counts().head(10)
# Out:
# Region
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Name: count, dtype: int64

# %%
terrorism_df['State'].value_counts().head(10)
# Out:
# State
# Baghdad               7645
# Unknown               4712
# Northern Ireland      4498
# Balochistan           3710
# Saladin               3411
# Al Anbar              3299
# Nineveh               3241
# Sindh                 3206
# Khyber Pakhtunkhwa    3084
# Diyala                3041
# Name: count, dtype: int64

# %%
terrorism_df['Target_subtype'].value_counts().head(10)
# Out:
# Target_subtype
# Unnamed Civilian/Unspecified                               11596
# Police Security Forces/Officers                            11178
# Military Unit/Patrol/Convoy                                 8277
# Military Personnel (soldiers, troops, officers, forces)     7963
# Government Personnel (excluding police, military)           6610
# Village/City/Town/Suburb                                    6542
# Politician or Political Party Movement/Meeting/Rally        6306
# Police Building (headquarters, station, school)             5907
# Military Barracks/Base/Headquarters/Checkpost               5211
# Police Patrol (including vehicles and convoys)              5105
# Name: count, dtype: int64

# %%
terrorism_df['City'].value_counts().head(10)
# Out:
# City
# Unknown         10211
# Baghdad          7589
# Karachi          2652
# Lima             2359
# Mosul            2265
# Belfast          2171
# Santiago         1621
# Mogadishu        1581
# San Salvador     1558
# Istanbul         1048
# Name: count, dtype: int64

# %%
terrorism_df['Attack_type'].value_counts().head(10)
# Out:
# Attack_type
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: count, dtype: int64

# %%
terrorism_df['Target_type'].value_counts().head(10)
# Out:
# Target_type
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Name: count, dtype: int64

# %%
terrorism_df['Gang_name'].value_counts().head(10)
# Out:
# Gang_name
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Al-Shabaab                                           3288
# New People's Army (NPA)                              2772
# Irish Republican Army (IRA)                          2671
# Revolutionary Armed Forces of Colombia (FARC)        2487
# Boko Haram                                           2418
# Name: count, dtype: int64

# %%
terrorism_df['Weapon_type'].value_counts().head(5)
# Out:
# Weapon_type
# Explosives    92426
# Firearms      58524
# Unknown       15157
# Incendiary    11135
# Melee          3655
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
plt.figure(figsize=(20,5));
sns.countplot(x=terrorism_df.Weapon_type);

# %%
plt.figure(figsize=(20,5));
plt.xticks(rotation = 90)
plt.title('Attacks by Year')
sns.countplot(x=terrorism_df.Year);

# %%
plt.figure(figsize=(20,5));
plt.title('Attacks by Month')
sns.countplot(x=terrorism_df.Month);

# %%
plt.figure(figsize=(20,5));
plt.title('Attacks by Day')
sns.countplot(x=terrorism_df.Day);

# %%
plt.figure(figsize=(30,5));
plt.rcParams.update({'font.size':8});
plt.xticks(rotation = 90)
plt.title('Attacks by Country')
sns.countplot(x=terrorism_df.Country);

# %%
plt.figure(figsize=(28,5));
plt.rcParams.update({'font.size':10});
plt.xticks(rotation = 0)
plt.title('Attacks by Region')
sns.countplot(x=terrorism_df.Region);

# %%
plt.figure(figsize=(20,5));
plt.rcParams.update({'font.size':10});
plt.xticks(rotation = 90)
plt.title('Based on Target type')
sns.countplot(x=terrorism_df.Target_type);

# %%
plt.figure(figsize=(25,5));
plt.rcParams.update({'font.size':12});
plt.xticks(rotation = 0)
plt.title('Based on Attack type')
sns.countplot(x=terrorism_df.Attack_type);

# %% [markdown]
# Results of Analysis
#
# 1.Most of the attacks were attacked through explosives and then through firearms.
#
# 2.Attacks were more during 2014 and then in 2015. When compared to attacks from 1970 onwards, the last 6 years scored a maximum. But from 2014 onwards count started decreasing.
#
# 3.Almost Every day has the same contribution but attacks were low during 31st and high during 15th and 1st.
#
# 4.Iraq dominates all the countries and it has the highest number of attacks and then Pakistan, Afghanistan, and India follow it.
#
# 5.The Middle East& North Africa leads 1st among all the regions and then South Asia takes 2nd place.
#
# 6.For most of the attacks, the target is Private Citizens& property and the next Military leads.
#
# 7.Most of the attacks were through either Bombing or Explosion.
